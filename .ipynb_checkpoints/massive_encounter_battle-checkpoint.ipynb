# %%
import pandas as pd
import numpy as np
import csv
import random

# %%
monster_stats = "combat_stats/monsters.csv"
intiative_order = "combat_stats/initiative_rolls.csv"
# Read Purchasing File and store into Pandas data frame
encounter_data = pd.read_csv(monster_stats)
initiative_order = pd.read_csv(intiative_order)

# %%
# Initiative order

initiative_order.insert(2, 'attack roll', 1)
initiative_order.insert(2, 'damage roll', 1)
initiative_order
# Out:
#    creature name  initiative  damage roll  attack roll
# 0   Van Kutsnick          25            1            1
# 1          Orc13          24            1            1
# 2          Orc11          24            1            1
# 3          Orc31          24            1            1
# 4          Orc41          23            1            1
# 5          Orc39          23            1            1
# 6          Orc37          23            1            1
# 7          Orc23          22            1            1
# 8          Orc34          22            1            1
# 9           Orc1          22            1            1
# 10         Orc15          21            1            1
# 11         Orc32          20            1            1
# 12          Orc5          19            1            1
# 13         Orc29          19            1            1
# 14         Orc40          19            1            1
# 15         Orc30          18            1            1
# ...

# %%
purchase_Analysis = pd.DataFrame({"Purchase Count": Purchase_count, "Average Price": Purchase_mean, "Total Purchases": Purchase_total, "Avg Total Purchase per Person": PPP})

# %%
# Rolls
# make a for loop until you hit a player name
attack_roll = []
creature_list = []
#df.loc[df['a'] == 1, 'b'].sum()
for row in encounter_data.itertuples():
    rollD20 = 8
    rollD20_second = 25
    if rollD20>rollD20_second:
        advantage = rollD20
        disadvantage = rollD20_second
    else:
        advantage = rollD20_second
        disadvantage = rollD20
#    df.loc[df['column_name'] == some_value]
  #  if encounter_data.loc[encounter_data["combat condition"] == -1]:
  #      attack = disadvantage + encounter_data["dex mod"].mean()
  #  elif encounter_data["combat condition"].mean() == 1:
  #      attack = advantage + encounter_data["dex mod"].mean()
  #  else:
  #      attack = rollD20 + encounter_data["dex mod"].mean()
    encounter_data.loc[encounter_data['combat condition'] == 1, 'attack roll'] = advantage + encounter_data["dex mod"].mean()
    encounter_data.loc[encounter_data['combat condition'] == 0, 'attack roll'] = rollD20 + encounter_data["dex mod"].mean()
    encounter_data.loc[encounter_data['combat condition'] == -1, 'attack roll'] = disadvantage + encounter_data["dex mod"].mean()
    #  attack_roll.append(attack)
#print(index)
attack_roll
# Out:
# []

# %%
encounter_data
# Out:
#    monster_name  attack mod  damage mod  monster health  str mod  dex mod  \
# 0         Orc43           4           3               4        3        2
# 1         Orc42           4           3               4        3        2
# 2         Orc41           4           3               4        3        2
# 3         Orc40           4           3               4        3        2
# 4         Orc39           4           3               4        3        2
# 5         Orc38           4           3               4        3        2
# 6         Orc37           4           3               4        3        2
# 7         Orc36           4           3               4        3        2
# 8         Orc35           4           3               4        3        2
# 9         Orc34           4           3               4        3        2
# 10        Orc33           4           3               4        3        2
# 11        Orc32           4           3               4        3        2
# ...
